# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "resources/world_happiness.csv"
happiness_df = pd.read_csv(csv_file)
happiness_df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
# Drop columns that are not needed

happiness_df_new = happiness_df.drop(columns=["Social support", "Freedom to make life choices", "Generosity", "Perceptions of corruption"])

happiness_df_new
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Healthy life expectancy
# 0                      0.986
# 1                      0.996
# 2                      1.028
# 3                      1.026
# ...

# %%
# Rename columns & reset index

clean_happiness_df = happiness_df_new.rename(columns={"Overall rank": "Overall Happiness Rank",
                                                     "Score":"Overall Happiness Score",
                                                      "Country or region": "Country or Region",
                                                     "GDP per capita":"GDP Per Capita",
                                                     "Healthy life expectancy": "Life Expectancy"})

clean_happiness_df.head()
# Out:
#    Overall Happiness Rank Country or Region  Overall Happiness Score  \
# 0                       1           Finland                    7.769
# 1                       2           Denmark                    7.600
# 2                       3            Norway                    7.554
# 3                       4           Iceland                    7.494
# 4                       5       Netherlands                    7.488
#
#    GDP Per Capita  Life Expectancy
# 0           1.340            0.986
# 1           1.383            0.996
# 2           1.488            1.028
# 3           1.380            1.026
# 4           1.396            0.999

# %%
clean_happiness_df.set_index("Country or Region", inplace=True)

# %%
clean_happiness_df
# Out:
#                           Overall Happiness Rank  Overall Happiness Score  \
# Country or Region
# Finland                                        1                    7.769
# Denmark                                        2                    7.600
# Norway                                         3                    7.554
# Iceland                                        4                    7.494
# Netherlands                                    5                    7.488
# ...                                          ...                      ...
# Rwanda                                       152                    3.334
# Tanzania                                     153                    3.231
# Afghanistan                                  154                    3.203
# Central African Republic                     155                    3.083
# South Sudan                                  156                    2.853
#
#                           GDP Per Capita  Life Expectancy
# ...

# %%
# Save clean data to output file

clean_happiness_df.to_csv("happiness_csv", index=False)
